# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
sys.path.append('/home/chayan/Multi-VIS/')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from utills import Datasets as ds
from utills import NeuroDAVIS as nd

# %% [markdown]
# # Loading Data

# %%
x, y = ds.LoadData('Usoskin')

# %%
# Colorcodes
c1 = list(np.unique(y['leiden']))
c2=['blue', 'green', 'orange', 'red', 'yellow',
    'pink', 'purple', 'aquamarine', 'gray', 'violet',
    'cyan','lime', 'royalblue' , 'skyblue', 'olive',
    'tomato', 'saddlebrown', 'sienna', 'navy', 'darkgreen',
    'crimson', 'greenyellow','coral','burlywood','slategrey','blue', 'green']
cols = map(lambda x: c2[c1.index(x)], y['leiden'])
cs = [i for i in list(cols)]

# %% [markdown]
# # Applying NeuroDAVIS

# %%
X_embedding = nd.NeuroDAVIS(x, dim=2, lambda_act= 0, lambda_weight= 0, num_neuron=[100, 200],
                          bs=128, epoch=500, sd=0, verbose=1)

# saving the embedding
pd.DataFrame(X_embedding).to_csv('/home/chayan/Multi-VIS/Data/Single Omics/Embeddings/Usoskin_NeuroDAVIS.csv')
# Out:
# Epoch 1/500
# 5/5 [==============================] - 1s 11ms/step - loss: 0.8965
# Epoch 2/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8952
# Epoch 3/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8950
# Epoch 4/500
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8949
# Epoch 5/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8949
# Epoch 6/500
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8948
# Epoch 7/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8948
# Epoch 8/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8947
# Epoch 9/500
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8946
# Epoch 10/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8945
# Epoch 11/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8943
# Epoch 12/500
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8941
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_embedding[:,0],X_embedding[:,1],c=cs,s=5)
plt.xlabel("MultiVIS1", fontsize=16)
plt.ylabel("MultiVIS2", fontsize=16)
plt.savefig('/home/chayan/Multi-VIS/Results/Plots/Usoskin_NeuroDAVIS.eps',
            dpi = 1200, format = 'eps')
